# %% [markdown]
# # 01 EDA
# Guided steps:
# 1) Load CSVs from `data/raw`
# 2) Check shapes, dtypes, missing values
# 3) Basic joins and sanity checks
# 4) Quick plots and save figures to `images/`

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
raw = Path('../data/raw')
orders = pd.read_csv(raw/'orders.csv') # replace with your file name
orders.head()
