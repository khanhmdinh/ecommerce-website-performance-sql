# %% [markdown]
# # 02 Visualization
# Create charts for key KPIs and export PNGs to `../images`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
# Example placeholder: plot daily revenue after you compute it
# Save figures as PNGs
